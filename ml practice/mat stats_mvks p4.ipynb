# %%
#mat stats mvks

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats

#define the matrix
np.random.seed(42)
mat=np.random.rand(100,10)

#convert mat into df
data=pd.DataFrame(mat)

#calc
mean=data.mean()
varience=data.var()
kurtosis=stats.kurtosis(data)
skewness=stats.skew(data)

#print
print("mean:")
print(mean)
print("\nvarience:")
print(varience)
print("\nkurtosis:")
print(kurtosis)
print("\nskewness:")
print(skewness)

print("\noverall mean:",np.mean(mean))
print("\noverall varience:",np.var(varience))
print("\noverall kurtosis:",stats.kurtosis(kurtosis))
print("\noverall skewness:",stats.skew(skewness))

#plotting
plt.figure(figsize=(12,8))
plt.plot(mean,label="mean",marker='o')
plt.plot(varience,label="varience",marker='o')
plt.plot(kurtosis,label="kurtosis",marker='o')
plt.plot(skewness,label="skewness",marker='o')
plt.title("plotting mvks")
plt.legend()
plt.grid(True)
plt.show()

#his
fig,axs=plt.subplots(2,2,figsize=(12,8))

#mean
axs[0,0].hist(mean,bins=10,alpha=0.7)
axs[0,0].set_xlabel("mean")
axs[0,0].set_ylabel("freq")
axs[0,0].set_title("histogram of mean")

#var
axs[0,1].hist(varience,bins=10,alpha=0.7)
axs[0,1].set_xlabel("varience")
axs[0,1].set_ylabel("freq")
axs[0,1].set_title("histogram of varience")

#skewness
axs[1,0].hist(kurtosis,bins=10,alpha=0.7)
axs[1,0].set_xlabel("kurtosis")
axs[1,0].set_ylabel("freq")
axs[1,0].set_title("histogram of kurtosis")

#skewness
axs[1,1].hist(skewness,bins=10,alpha=0.7)
axs[1,1].set_xlabel("skewness")
axs[1,1].set_ylabel("freq")
axs[1,1].set_title("histogram of skewness")

plt.tight_layout()
plt.show()
# Out:
# mean:
# 0    0.458303
# 1    0.559489
# 2    0.452279
# 3    0.510929
# 4    0.450673
# 5    0.525704
# 6    0.470577
# 7    0.508199
# 8    0.505500
# 9    0.460913
# dtype: float64
#
# varience:
# 0    0.090321
# 1    0.085255
# 2    0.084614
# 3    0.068868
# 4    0.088703
# 5    0.087642
# 6    0.082123
# 7    0.081335
# 8    0.096051
# 9    0.083854
# dtype: float64
#
# kurtosis:
# [-1.30515265 -1.08273166 -1.15214819 -1.01476521 -1.24796822 -1.206287
#  -1.1994045  -1.19017366 -1.28508739 -1.30001506]
#
# skewness:
# [ 0.10068414 -0.27596554  0.22444134  0.04043766  0.21263727 -0.0178336
#   0.10794732 -0.05880564 -0.07169176  0.17584718]
#
# overall mean: 0.4902565533201336
#
# overall varience: 4.5446003618231554e-05
#
# overall kurtosis: -0.5359635547772896
#
# overall skewness: -0.696049325821991
