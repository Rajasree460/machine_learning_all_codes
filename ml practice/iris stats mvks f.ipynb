# %%
#iris stats mvks

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats

#load the ds
data=pd.read_csv("C:/Users/HP/OneDrive/Desktop/ml 7th sem codes/datasets/iris.csv")
data
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
#data.head()

# %%
#drop the cl
data=data.drop('variety',axis=1)
data
# Out:
#      sepal.length  sepal.width  petal.length  petal.width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
#calc(colwise mvks)
mean=data.mean()
var=data.var()
kurto=stats.kurtosis(data)
skew=stats.skew(data)

# %%
#print
print("mean:")
print(mean)
print("var:")
print(var)
print("kurto:")
print(kurto)
print("skew:")
print(skew)

print("\noverall mean:",np.mean(mean))
print("\noverall var:",np.var(var))
print("\noverall kurto:",stats.kurtosis(kurto))
print("\noverall skew:",stats.skew(skew))
# Out:
# mean:
# sepal.length    5.843333
# sepal.width     3.057333
# petal.length    3.758000
# petal.width     1.199333
# dtype: float64
# var:
# sepal.length    0.685694
# sepal.width     0.189979
# petal.length    3.116278
# petal.width     0.581006
# dtype: float64
# kurto:
# [-0.57356795  0.18097632 -1.39553589 -1.33606741]
# skew:
# [ 0.31175306  0.31576711 -0.27212767 -0.10193421]
#
# overall mean: 3.4645000000000006
#
# overall var: 1.3317599164143141
#
# overall kurto: -1.3980510418361585
#
# overall skew: -0.159158086545934

# %%
#plot
plt.figure(figsize=(12,8))
plt.plot(mean,label="mean",marker='o')
plt.plot(var,label="var",marker='o')
plt.plot(kurto,label="kurtosis",marker='s')
plt.plot(skew,label="skewness",marker='x')
plt.title("plotting mvks")
plt.legend()
plt.grid(True)
plt.show()
